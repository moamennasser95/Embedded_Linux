# %% [markdown]
# # Hough Circle Lab
#
# ## Goal
#
# The goal of this lab is to detect as much circles as possible. The more you detect, the higher your grade.
#
# So, using the following image tune the parameters to get as much circles as you can:
#
# ![Hough Circles](Files/Hough/circles.png)
#
# ## Grade
#
# 26
#
# ## Note
#
# Each circle you get right it's +1 and each false circle you get -1.

# %%
import numpy as np
import cv2

def nothing(x):
    pass


img = cv2.imread('Files/Hough/circles.png',0)
img = cv2.medianBlur(img,5)  ###################### Median Filter


cv2.namedWindow('output')
cv2.createTrackbar('x', 'output', 1, 100, nothing)
cv2.createTrackbar('y', 'output', 12, 100, nothing)
cv2.createTrackbar('param1', 'output', 85, 100, nothing)
cv2.createTrackbar('param2', 'output', 17, 100, nothing)
cv2.createTrackbar('minR', 'output', 21, 100, nothing)
cv2.createTrackbar('maxR', 'output', 33, 100, nothing)

while 1:
    cimg = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
    
    x = cv2.getTrackbarPos('x', 'output')
    y = cv2.getTrackbarPos('y', 'output')
    param1 = cv2.getTrackbarPos('param1', 'output')
    param2 = cv2.getTrackbarPos('param2', 'output')
    minR = cv2.getTrackbarPos('minR', 'output')
    maxR = cv2.getTrackbarPos('maxR', 'output')

    if x < 1:
        x = 1
    if y < 1:
        y = 1
    if param1 < 1:
        param1 = 1
    if param2 < 1:
        param2 = 1
    if minR > maxR:
        minR = maxR - 1
    circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT, x, y,
                            param1=param1,param2=param2,minRadius=minR,maxRadius=maxR)

    if circles is not None:
        print(circles.shape)
        circles = np.uint16(np.around(circles))

        for i in circles[0,:]:
            # draw the outer circle
            cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
            # draw the center of the circle
            cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

    cv2.imshow('output', cimg)
    
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break

cv2.imwrite("Image.jpg" ,cimg )

cv2.destroyAllWindows()
# Out:
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)
# (1, 26, 3)

# %%
import numpy as np
import cv2

def nothing(x):
    pass


img = cv2.imread('Files/Hough/Capture.PNG',0)
img = cv2.medianBlur(img,5)

cv2.namedWindow('output')
cv2.createTrackbar('x', 'output', 1, 100, nothing)
cv2.createTrackbar('y', 'output', 30, 100, nothing)
cv2.createTrackbar('param1', 'output', 10, 100, nothing)
cv2.createTrackbar('param2', 'output', 16, 100, nothing)
cv2.createTrackbar('minR', 'output', 7, 100, nothing)
cv2.createTrackbar('maxR', 'output', 40, 100, nothing)

while 1:
    cimg = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
    
    x = cv2.getTrackbarPos('x', 'output')
    y = cv2.getTrackbarPos('y', 'output')
    param1 = cv2.getTrackbarPos('param1', 'output')
    param2 = cv2.getTrackbarPos('param2', 'output')
    minR = cv2.getTrackbarPos('minR', 'output')
    maxR = cv2.getTrackbarPos('maxR', 'output')

    if x < 1:
        x = 1
    if y < 1:
        y = 1
    if param1 < 1:
        param1 = 1
    if param2 < 1:
        param2 = 1
    if minR > maxR:
        minR = maxR - 1

        ##### Half GRADIENT
        ##### 
    circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT, x, y,
                            param1=param1,param2=param2,minRadius=minR,maxRadius=maxR)
    if circles is not None:
        print (circles.shape)
        circles = np.uint16(np.around(circles))

        for i in circles[0,:]:
            # draw the outer circle
            cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
            # draw the center of the circle
            cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

    cv2.imshow('output', cimg)
    
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break

cv2.imwrite("Image2.jpg" ,cimg )

cv2.destroyAllWindows()
# Out:
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
# (1, 54, 3)
